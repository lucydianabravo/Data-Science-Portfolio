# %%
chaviza = ["Ale", "Briza", "Christian", "Alex", "Sam", "Omar"]
chaviza
# Out:
# ['Ale', 'Briza', 'Christian', 'Alex', 'Sam', 'Omar']

# %%
elementos = ["pato", "cabipara", 2, "pastel", "pase", 69]
elementos
# Out:
# ['pato', 'cabipara', 2, 'pastel', 'pase', 69]

# %%
print(chaviza[2])
# Out:
# Christian

# %%
chaviza2 = chaviza
chaviza[4] = "Desconocido"
chaviza2
# Out:
# ['Ale', 'Briza', 'Christian', 'Alex', 'Desconocido', 'Omar']

# %%
longitud = len(chaviza)
longitud
# Out:
# 6

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c[1:3]
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c[2:]
# Out:
# [3, 4, 5, 6]

# %%
type(c)
# Out:
# list

# %%
listado = list()
listado
# Out:
# []

# %%
listado.append("pase usted")
listado.append(100)
listado
# Out:
# ['pase usted', 100]

# %%
chaviza
# Out:
# ['Ale', 'Briza', 'Christian', 'Alex', 'Desconocido', 'Omar']

# %%
chaviza.sort()
chaviza
# Out:
# ['Ale', 'Alex', 'Briza', 'Christian', 'Desconocido', 'Omar']

# %%
print(max(c))
# Out:
# 6

# %%
print(sum(c))
# Out:
# 21
