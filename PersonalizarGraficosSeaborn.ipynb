# %%
import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import seaborn as sns
for style in ["dark", "whitegrid", "darkgrid", "ticks"]:
    sns.set_style(style)
    sns.displot(df["reading score"])

# %%
#Remocion de ejes
sns.set_style("ticks")
sns.displot(df["reading score"], kde=True)
sns.despine(left=True, bottom=True)

# %%
#Combinacion de seaborn con matplotlib
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
sns.distplot(df["writing score"], ax = ax)
ax.set(xlabel = "Score de escritura", ylabel="Frecuencia relativa")
# Out:
# C:\Users\SURFACE\AppData\Local\Temp\ipykernel_19832\2041605592.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax = ax)
# [Text(0.5, 0, 'Score de escritura'), Text(0, 0.5, 'Frecuencia relativa')]

# %%
#Truncamiento de escala de visualización
fig, ax = plt.subplots()
sns.distplot(df["writing score"], ax = ax)
ax.set(xlabel = "Score de escritura", ylabel="Frecuencia relativa", xlim=(0,90), title="Histograma de frecuencias para puntajes de escritura")
# Out:
# C:\Users\SURFACE\AppData\Local\Temp\ipykernel_19832\2891168265.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax = ax)
# [Text(0.5, 0, 'Score de escritura'),
#  Text(0, 0.5, 'Frecuencia relativa'),
#  (0.0, 90.0),
#  Text(0.5, 1.0, 'Histograma de frecuencias para puntajes de escritura')]

# %%
fig, (ax0,ax1) = plt.subplots(nrows=1, ncols=2, sharey=True)
sns.distplot(df["writing score"], ax=ax0) #Histograma para todas las observaciones
sns.distplot(df.query('gender== male')["writing score"], ax=ax1) #Histograma para hombres
ax0.set(xlabel="Puntaje general de escritura")
ax1.set(xlabel="Puntaje de escritura para hombres")
ax1.axvline(x=75, label= "Objetivo", linestyle="--")
ax1.legend()
# Out:
# C:\Users\SURFACE\AppData\Local\Temp\ipykernel_19832\3333961160.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax=ax0) #Histograma para todas las observaciones
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
# ...

# %%
#Asignacion de colores al histograma
paleta =["deep", "muted", "pastel", "bright", "dark", "colorblind"]
for p in paleta:
    sns.set_palette(p)
    sns.displot(df["reading score"], kde=True)
