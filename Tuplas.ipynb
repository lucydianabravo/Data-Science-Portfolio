# %%
x = ("Lucy", "Diana", "Berenice")
x
# Out:
# ('Lucy', 'Diana', 'Berenice')

# %%
print(x[2])
# Out:
# Berenice

# %%
y = (1, 41, 69)
print(max(y))
# Out:
# 69

# %%
z = "ABC"
z[2] = "D"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 z = "ABC"
# ----> 2 z[2] = "D"
#
# TypeError: 'str' object does not support item assignment

# %%
y[1] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y[1] = 15
#
# TypeError: 'tuple' object does not support item assignment

# %%
y.append(68)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y.append(68)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
y.dir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y.dir()
#
# AttributeError: 'tuple' object has no attribute 'dir'

# %%
dir(y=
# Out:
#   Cell In[8], line 1
#     dir(y=
#           ^
# _IncompleteInputError: incomplete input

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
(x,y) = (0, "hola pendejo")
print(y)
# Out:
# hola pendejo

# %%
diccionario = dict()
diccionario["Terry"] = 100
diccionario["Anthony"] = 200
diccionario
# Out:
# {'Terry': 100, 'Anthony': 200}

# %%
tuplas = diccionario.items()
tuplas
# Out:
# dict_items([('Terry', 100), ('Anthony', 200)])

# %%
d = {"l": 1, "u":2, "c":3, "d":4}
tuplas = sorted(d.items())
tuplas
# Out:
# [('c', 3), ('d', 4), ('l', 1), ('u', 2)]
